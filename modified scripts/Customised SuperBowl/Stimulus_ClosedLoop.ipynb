# %%
import pandas as pd
import os
from sys import path
path.append(r'C:\Users\fenklab\Desktop\super_bowl_screen-main\Software')
from bowl_stimulate_class import *

Arena = Stimulation_Pipeline()
log = Arena.RotateWithFicTrac(Arena.bar_vertical(width=30, color=0, color_b=125),
                              inverted=True, MMapName="2305",
                              gain=1, duration=-1, rot_offset=(0,50,0))

if len(sys.argv) > 1:
    # Extract command-line arguments
    output_directory_path = sys.argv[1]
    flyID = sys.argv[2]
    #log.to_csv(os.path.join(output_directory_path, flyID + "_" + 'stimulus_log.csv'), index=False)
    log.to_csv(os.path.join(r'C:\Users\fenklab\Desktop', 'FICTRAC_TEST5.csv'), index=False)
    
cv2.destroyAllWindows()
key = cv2.waitKey(1)
# Out:
# initialize Stimulation Pipeline <  Arena  >: xdim=, 720 ydim= 360 at position x= 7080 y= 2400
# starting time:- 2024-01-26 11:22:57.462550
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# 2305 is not connected
# mean fps74.39694077545265
